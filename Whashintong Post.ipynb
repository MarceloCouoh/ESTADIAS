# %%
from urllib.request import urlopen

# %%
from urllib.error import HTTPError

# %%
from bs4 import BeautifulSoup

# %%
try:

    html = urlopen("https://www.washingtonpost.com/")
    
except HTTPError as e:

    print(e)

else:

    res = BeautifulSoup(html.read(),"html")

    print(res.title)
# Out:
# <title>Washington Post: Breaking News, World, US, DC News &amp; Analysis - The Washington Post</title>

# %%
tags = res.findAll("h2", {"class": "headline"})

# %%
from urllib.request import urlopen

from urllib.error import HTTPError

from urllib.error import URLError

from bs4 import BeautifulSoup

try:

    html = urlopen("https://www.washingtonpost.com/")

except HTTPError as e:

    print(e)

except URLError:

    print("Server down or incorrect domain")

else:

    res = BeautifulSoup(html.read(),"html")

    tags = res.findAll("h2", {"class": "headline"})

# %%
for tag in tags:

        print(tag.getText())
# Out:
# What is happening in Hong Kong?
# Young adults are also affected by Kawasaki-like disease linked to covid-19, doctors say
# White House economic adviser sounds uncertain about recovery despite Trump’s confidence
# Living through a pandemic when getting water is difficult
# Facebook will now let some employees work from anywhere, but their paychecks could get cut
# Delta, JetBlue criticized for cutting employee hours after getting billions in virus relief
# Guide to the pandemic
# Legacy retail begins its collapse
# U.S. to withdraw from Open Skies arms-control treaty
# Supply company asks Maryland to restore its contract for covid-19 equipment
# Senate confirms John Ratcliffe as next director of national intelligence in sharply divided vote
# Mich. governor says state will seek ‘legal recourse’ over failed dam
# Being a pig farmer was already hard. Then came coronavirus.
# 30 years ago today, Fauci took heat from violent protesters over AIDS drugs
# ...

# %%
import pandas as pd

# %%
weather = pd.DataFrame({
    "noticias": tags,
   
})
weather
# Out:
#                                              noticias
# 0                [[What is happening in Hong Kong? ]]
# 1   [[Young adults are also affected by Kawasaki-l...
# 2   [[White House economic adviser sounds uncertai...
# 3   [[Living through a pandemic when getting water...
# 4   [[Facebook will now let some employees work fr...
# 5   [[Delta, JetBlue criticized for cutting employ...
# 6                           [[Guide to the pandemic]]
# 7               [[Legacy retail begins its collapse]]
# 8   [[U.S. to withdraw from Open Skies arms-contro...
# 9   [[Supply company asks Maryland to restore its ...
# 10  [[Senate confirms John Ratcliffe as next direc...
# 11  [[Mich. governor says state will seek ‘legal r...
# 12  [[Being a pig farmer was already hard. Then ca...
# 13  [[30 years ago today, Fauci took heat from vio...
# 14  [[Senate panel approves nominee to oversee med...
# 15  [[Cohen released from federal prison over viru...
# ...
